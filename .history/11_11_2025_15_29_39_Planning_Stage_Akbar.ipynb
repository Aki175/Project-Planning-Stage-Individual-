# %% [markdown]
# # Planning Stage Akbar Ismatullayev 17376021 #

# %%
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
# source("cleanup.R")

# %% [markdown]
# ### Reading the data for analysing

# %%
players <- read_csv("data/players.csv")
sessions <- read_csv("data/sessions.csv")

sessions
players

# %% [markdown]
# ## Project statement ##

# %% [markdown]
# This project investigates player behaviour on the UBC Minecraft research server. Specifically, it aims to identify which kinds of players are most likely to contribute a large amount of data to the server. Understanding this can help the research team target recruitment toward highly active players and optimize server resource planning.

# %% [markdown]
# ### (1) Data Description: ###

# %%
glimpse(players)
glimpse(sessions)

# %% [markdown]
# This project used two related datasets, players.csv and sessions.csv. They together describe player characteristics and their activity on a Minecraft server hosted by UBC.
#
# player.csv contains demographic and behavioural information about each unique player (e.g., age, gender, country, experience, or registration details). Each row represents one player.
